# %% [markdown]
# <a href="https://colab.research.google.com/github/wongpinter/google-client/blob/master/Transfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================= FORM ============================= #
#@markdown ← Install rclone

build_version = 'stable' #@param ["stable", "beta"]

# ================================================================ #

from IPython.display import clear_output, display, HTML


def main():
    clear_output()

    if build_version == 'stable':
        # !curl https://rclone.org/install.sh | sudo bash
    else:
        # !curl https://rclone.org/install.sh | sudo bash -s beta
    # !sudo apt-get -y install fuse3

    try:
        # !mkdir -p /root/.config/rclone
        # !cp /content/drive/MyDrive/rclone.conf /root/.config/rclone
    except Exception as error:
        display(HTML(f'[ERROR]: ❌ {error} '))
    else:
        clear_output()
        display(HTML(f'[NOTICE]: ✅ Successfully installed rclone'))


if __name__ == '__main__':
    main()
# Out:
# [NOTICE]: ✅ Successfully installed rclone

# %%
# ============================= FORM ============================= #
# @markdown ← [Start] rclone
Mode = "Copy" #@param ["Copy", "Move", "Sync", "Checker", "Deduplicate", "Remove Empty Directories", "Empty Trash"]
Source = "/content/drive/MyDrive/GDFlix" #@param {type:"string"}
Destination = "mr_drive:" #@param {type:"string"}

#@markdown ---
#@markdown ⚙️ Global Configuration ⚙️
Extra_Arguments = "" #@param {type:"string"}
Compare = "Size & Mod-Time" #@param ["Size & Mod-Time", "Size & Checksum", "Only Mod-Time", "Only Size", "Only Checksum"]
Checkers = 5 #@param {type:"slider", min:1, max:40, step:1}
Transfers = 5 #@param {type:"slider", min:1, max:20, step:1}
Dry_Run = False #@param {type:"boolean"}
Do_not_cross_filesystem_boundaries = False
Do_not_update_modtime_if_files_are_identical = False #@param {type:"boolean"}
Google_Drive_optimization = False #@param {type:"boolean"}
Large_amount_of_files_optimization = False #@param {type:"boolean"}
Simple_Ouput = True #@param {type:"boolean"}
Skip_all_files_that_exist = False #@param {type:"boolean"}
Skip_files_that_are_newer_on_the_destination = False #@param {type:"boolean"}
Output_Log_File = "OFF" #@param ["OFF", "NOTICE", "INFO", "ERROR", "DEBUG"]

#@markdown ↪️ Sync Configuration ↩️
Sync_Mode = "Delete during transfer" #@param ["Delete during transfer", "Delete before transfering", "Delete after transfering"]
Track_Renames = False #@param {type:"boolean"}

#@markdown 💞 Deduplicate Configuration 💞
Deduplicate_Mode = "Interactive" #@param ["Interactive", "Skip", "First", "Newest", "Oldest", "Largest", "Rename"]
Deduplicate_Use_Trash = True #@param {type:"boolean"}

#@markdown ---
automatically_clear_cell_output = False  # @param{type: "boolean"}
# ================================================================ #

##### Importing the needed modules
import os
import IPython
from IPython.display import HTML, clear_output


##### Variable Declaration
# Optimized for Google Colaboratory
os.environ["bufferC"] = "--buffer-size 96M"

if Compare == "Size & Checksum":
    os.environ["compareC"] = "-c"
elif Compare == "Only Mod-Time":
    os.environ["compareC"] = "--ignore-size"
elif Compare == "Only Size":
    os.environ["compareC"] = "--size-only"
elif Compare == "Only Checksum":
    os.environ["compareC"] = "-c --ignore-size"
else:
    os.environ["compareC"] = ""

os.environ["sourceC"] = Source
os.environ["destinationC"] = Destination
os.environ["transfersC"] = "--transfers "+str(Transfers)
os.environ["checkersC"] = "--checkers "+str(Checkers)

if Skip_files_that_are_newer_on_the_destination == True:
    os.environ["skipnewC"] = "-u"
else:
    os.environ["skipnewC"] = ""

if Skip_all_files_that_exist == True:
    os.environ["skipexistC"] = "--ignore-existing"
else:
    os.environ["skipexistC"] = ""

if Do_not_cross_filesystem_boundaries == True:
    os.environ["nocrossfilesystemC"] = "--one-file-system"
else:
    os.environ["nocrossfilesystemC"] = ""

if Do_not_update_modtime_if_files_are_identical == True:
    os.environ["noupdatemodtimeC"] = "--no-update-modtime"
else:
    os.environ["noupdatemodtimeC"] = ""

if Large_amount_of_files_optimization == True:
    os.environ["filesoptimizeC"] = "--fast-list"
else:
    os.environ["filesoptimizeC"] = ""

if Google_Drive_optimization == True:
    os.environ["driveoptimizeC"] = "--drive-chunk-size 32M --drive-acknowledge-abuse --drive-keep-revision-forever"
else:
    os.environ["driveoptimizeC"] = ""

if Dry_Run == True:
    os.environ["dryrunC"] = "-n"
else:
    os.environ["dryrunC"] = ""

if Output_Log_File != "OFF":
    os.environ["statsC"] = "--log-file=/root/.rclone_log/rclone_log.txt"
else:
    if Simple_Ouput == True:
        os.environ["statsC"] = "-v --stats-one-line --stats=5s"
    else:
        os.environ["statsC"] = "-v --stats=5s"

if Output_Log_File == "INFO":
    os.environ["loglevelC"] = "--log-level INFO"
elif Output_Log_File == "ERROR":
    os.environ["loglevelC"] = "--log-level ERROR"
elif Output_Log_File == "DEBUG":
    os.environ["loglevelC"] = "--log-level DEBUG"
else:
    os.environ["loglevelC"] = ""

os.environ["extraC"] = Extra_Arguments

if Sync_Mode == "Delete during transfer":
    os.environ["syncmodeC"] = "--delete-during"
elif Sync_Mode == "Delete before transfering":
    os.environ["syncmodeC"] = "--delete-before"
elif Sync_Mode == "Delete after transfering":
    os.environ["syncmodeC"] = "--delete-after"

if Track_Renames == True:
    os.environ["trackrenamesC"] = "--track-renames"
else:
    os.environ["trackrenamesC"] = ""

if Deduplicate_Mode == "Interactive":
    os.environ["deduplicateC"] = "interactive"
elif Deduplicate_Mode == "Skip":
    os.environ["deduplicateC"] = "skip"
elif Deduplicate_Mode == "First":
    os.environ["deduplicateC"] = "first"
elif Deduplicate_Mode == "Newest":
    os.environ["deduplicateC"] = "newest"
elif Deduplicate_Mode == "Oldest":
    os.environ["deduplicateC"] = "oldest"
elif Deduplicate_Mode == "Largest":
    os.environ["deduplicateC"] = "largest"
elif Deduplicate_Mode == "Rename":
    os.environ["deduplicateC"] = "rename"

if Deduplicate_Use_Trash == True:
    os.environ["deduplicatetrashC"] = ""
else:
    os.environ["deduplicatetrashC"] = "--drive-use-trash=false"


##### rclone Execution
if Output_Log_File != "OFF" and Mode != "Config":
    # !mkdir -p -m 666 /root/.rclone_log/
    display(HTML("Logging enabled, rclone will no longer display any output on the terminal.Please wait until the cell stop by itself."))

if Mode == "Copy":
    # !rclone --config=/root/.config/rclone/rclone.conf copy "$sourceC" "$destinationC" checkersC loglevelC skipnewC nocrossfilesystemC bufferC driveoptimizeC extraC
elif Mode == "Move":
    # !rclone --config=/root/.config/rclone/rclone.conf move "$sourceC" "$destinationC" checkersC loglevelC --delete-empty-src-dirs skipnewC nocrossfilesystemC bufferC driveoptimizeC extraC
elif Mode == "Sync":
    # !rclone --config=/root/.config/rclone/rclone.conf sync "$sourceC" "$destinationC" checkersC loglevelC trackrenamesC skipnewC nocrossfilesystemC bufferC driveoptimizeC extraC
elif Mode == "Checker":
    # !rclone --config=/root/.config/rclone/rclone.conf check "$sourceC" "$destinationC" statsC compareC skipexistC noupdatemodtimeC filesoptimizeC dryrunC $extraC
elif Mode == "Deduplicate":
    # !rclone --config=/root/.config/rclone/rclone.conf dedupe "$sourceC" statsC deduplicateC compareC skipexistC noupdatemodtimeC filesoptimizeC dryrunC $extraC
elif Mode == "Remove Empty Directories":
    # !rclone --config=/root/.config/rclone/rclone.conf rmdirs "$sourceC" loglevelC extraC
elif Mode == "Empty Trash":
    # !rclone --config=/root/.config/rclone/rclone.conf cleanup "$sourceC" loglevelC extraC


##### Log Output
if Output_Log_File != "OFF" and Mode != "Config":

    ##### Rename log file and output settings.
    # !mv /root/.rclone_log/rclone_log.txt /root/.rclone_log/rclone_log_$(date +%Y-%m-%d_%H.%M.%S).txt
    with open("/root/.rclone_log/" + Mode + "_settings.txt", "w") as f:
        f.write("Mode: " + Mode + \
            "\nCompare: " + Compare + \
            "\nSource: \"" + Source + \
            "\"\nDestination: \"" + Destination + \
            "\"\nTransfers: " + str(Transfers) + \
            "\nCheckers: " + str(Checkers) + \
            "\nSkip files that are newer on the destination: " + str(Skip_files_that_are_newer_on_the_destination) + \
            "\nSkip all files that exist: " + str(Skip_all_files_that_exist) + \
            "\nDo not cross filesystem boundaries: " + str(Do_not_cross_filesystem_boundaries) + \
            "\nDo not update modtime if files are identical: " + str(Do_not_update_modtime_if_files_are_identical) + \
            "\nDry-Run: " + str(Dry_Run) + \
            "\nOutput Log Level: " + Output_Log_File + \
            "\nExtra Arguments: \"" + Extra_Arguments + \
            "\"\nSync Moden: " + Sync_Mode + \
            "\nTrack Renames: " + str(Track_Renames) + \
            "\nDeduplicate Mode: " + Deduplicate_Mode + \
            "\nDeduplicate Use Trash: " + str(Deduplicate_Use_Trash))

    ##### Compressing log file.
    # !rm -f /root/rclone_log.zip
    # !zip -r -q -j -9 /root/rclone_log.zip /root/.rclone_log/
    # !rm -rf /root/.rclone_log/
    # !mkdir -p -m 666 /root/.rclone_log/

    ##### Send Log
    if os.path.isfile("/root/rclone_log.zip") == True:
        try:
            files.download("/root/rclone_log.zip")
            # !rm -f /root/rclone_log.zip
            display(HTML("Sending log to your browser..."))
        except:
            # !mv /root/rclone_log.zip /content/rclone_log_$(date +%Y-%m-%d_%H.%M.%S).zip
            display(HTML("You can use file explorer to download the log file."))
    else:
        clear_output()
        display(HTML("There is no log file."))


### Operation has been successfully completed.
if Mode != "Config":
    display(HTML("✅ Operation has been successfully completed."))


##### Automatically clear terminal output if the checkbox's value on the top is set to True.
if automatically_clear_cell_output is True:
    clear_output()
else:
	pass##### Automatically clear terminal output if the checkbox's value on the top is set to True.
if automatically_clear_cell_output is True:
    clear_output()
else:
	pass
# Out:
# Usage:
#   rclone copy source:path dest:path [flags]
#
# Flags:
#       --create-empty-src-dirs   Create empty source dirs on destination after copy
#   -h, --help                    help for copy
#
#
# # Copy Flags
#
# Flags for anything which can Copy a file.
#
#       --check-first                                 Do all the checks before starting transfers
#   -c, --checksum                                    Check for changes with size & checksum (if available, or fallback to size only).
#       --compare-dest stringArray                    Include additional comma separated server-side paths during comparison
#       --copy-dest stringArray                       Implies --compare-dest but also copies files from paths into destination
#       --cutoff-mode HARD|SOFT|CAUTIOUS              Mode to stop transfers when reaching the max transfer limit HARD|SOFT|CAUTIOUS (default HARD)
#       --ignore-case-sync                            Ignore case when synchronizing
#       --ignore-checksum                             Skip post copy check of checksums
#       --ignore-existing                             Skip all files that exist on destination
#       --ignore-size                                 Ignore size when skipping use modtime or checksum
#   -I, --ignore-times                                Don't skip items that match size and time - transfer all unconditionally
#       --immutable                                   Do not modify files, fail if existing files have been modified
#       --inplace                                     Download directly to destination file instead of atomic download to temp/rename
#       --max-backlog int                             Maximum number of objects in sync or check backlog (default 10000)
#       --max-duration Duration                       Maximum duration rclone will transfer data for (default 0s)
#       --max-transfer SizeSuffix                     Maximum size of data to transfer (default off)
#   -M, --metadata                                    If set, preserve metadata when copying objects
#       --modify-window Duration                      Max time diff to be considered the same (default 1ns)
#       --multi-thread-chunk-size SizeSuffix          Chunk size for multi-thread downloads / uploads, if not set by filesystem (default 64Mi)
#       --multi-thread-cutoff SizeSuffix              Use multi-thread downloads for files above this size (default 256Mi)
#       --multi-thread-streams int                    Number of streams to use for multi-thread downloads (default 4)
#       --multi-thread-write-buffer-size SizeSuffix   In memory buffer size for writing when in multi-thread mode (default 128Ki)
#       --no-check-dest                               Don't check the destination, copy regardless
#       --no-traverse                                 Don't traverse destination file system on copy
#       --no-update-dir-modtime                       Don't update directory modification times
#       --no-update-modtime                           Don't update destination modtime if files identical
#       --order-by string                             Instructions on how to order the transfers, e.g. 'size,descending'
#       --partial-suffix string                       Add partial-suffix to temporary file name when --inplace is not used (default ".partial")
#       --refresh-times                               Refresh the modtime of remote files
#       --server-side-across-configs                  Allow server-side operations (e.g. copy) to work across different configs
#       --size-only                                   Skip based on size only, not modtime or checksum
#       --streaming-upload-cutoff SizeSuffix          Cutoff for switching to chunked upload if file size is unknown, upload starts after reaching cutoff or when file ends (default 100Ki)
#   -u, --update                                      Skip files that are newer on the destination
#
# # Important Flags
#
# Important flags useful for most commands.
#
#   -n, --dry-run         Do a trial run with no permanent changes
#   -i, --interactive     Enable interactive mode
#   -v, --verbose count   Print lots more stuff (repeat for more)
#
# # Filter Flags
#
# Flags for filtering directory listings.
#
#       --delete-excluded                     Delete files on dest excluded from sync
#       --exclude stringArray                 Exclude files matching pattern
#       --exclude-from stringArray            Read file exclude patterns from file (use - to read from stdin)
#       --exclude-if-present stringArray      Exclude directories if filename is present
#       --files-from stringArray              Read list of source-file names from file (use - to read from stdin)
#       --files-from-raw stringArray          Read list of source-file names from file without any processing of lines (use - to read from stdin)
#   -f, --filter stringArray                  Add a file filtering rule
#       --filter-from stringArray             Read file filtering patterns from a file (use - to read from stdin)
#       --ignore-case                         Ignore case in filters (case insensitive)
#       --include stringArray                 Include files matching pattern
#       --include-from stringArray            Read file include patterns from file (use - to read from stdin)
#       --max-age Duration                    Only transfer files younger than this in s or suffix ms|s|m|h|d|w|M|y (default off)
#       --max-depth int                       If set limits the recursion depth to this (default -1)
#       --max-size SizeSuffix                 Only transfer files smaller than this in KiB or suffix B|K|M|G|T|P (default off)
#       --metadata-exclude stringArray        Exclude metadatas matching pattern
#       --metadata-exclude-from stringArray   Read metadata exclude patterns from file (use - to read from stdin)
#       --metadata-filter stringArray         Add a metadata filtering rule
#       --metadata-filter-from stringArray    Read metadata filtering patterns from a file (use - to read from stdin)
#       --metadata-include stringArray        Include metadatas matching pattern
#       --metadata-include-from stringArray   Read metadata include patterns from file (use - to read from stdin)
#       --min-age Duration                    Only transfer files older than this in s or suffix ms|s|m|h|d|w|M|y (default off)
#       --min-size SizeSuffix                 Only transfer files bigger than this in KiB or suffix B|K|M|G|T|P (default off)
#
# # Listing Flags
#
# Flags for listing directories.
#
#       --default-time Time   Time to show if modtime is unknown for files and directories (default 2000-01-01T00:00:00Z)
#       --fast-list           Use recursive list if available; uses more memory but fewer transactions
#
#
# Additional help topics:
#
# Use "rclone [command] --help" for more information about a command.
# Use "rclone help flags" for to see the global flags.
# Use "rclone help backends" for a list of supported services.
# Command copy needs 2 arguments maximum: you provided 9 non flag arguments: ["/content/drive/MyDrive/GDFlix" "mr_drive:" "checkersC" "loglevelC" "skipnewC" "nocrossfilesystemC" "bufferC" "driveoptimizeC" "extraC"]
# ✅ Operation has been successfully completed.

# %%
# ============================= FORM ============================= #
# @markdown #### ⬅️ Execute rClone

Mode = "Sync"  # @param ["Move", "Copy", "Sync", "Verify", "Dedupe", "Clean Empty Dirs", "Empty Trash"]
Source = "mr_drive:sbToDrive"  # @param {type:"string"}
Destination = "tutor_drive:sbackup"  # @param {type:"string"}
Extra_Arguments = ""  # @param {type:"string"}
COPY_SHARED_FILES = False  # @param{type: "boolean"}
Compare = "Size & Checksum"
TRANSFERS, CHECKERS = 20, 20
THROTTLE_TPS = True
BRIDGE_TRANSFER = True  # @param{type: "boolean"}
FAST_LIST = False  # @param{type: "boolean"}
OPTIMIZE_GDRIVE = True
SIMPLE_LOG = True
RECORD_LOGFILE = False  # @param{type: "boolean"}
SKIP_NEWER_FILE = False
SKIP_EXISTED = False
SKIP_UPDATE_MODTIME = False
ONE_FILE_SYSTEM = False
LOG_LEVEL = "DEBUG"
SYNC_MODE = "Delete after transfering"
SYNC_TRACK_RENAME = True
DEDUPE_MODE = "Largest"
USE_TRASH = True
DRY_RUN = False  # @param{type: "boolean"}
# ================================================================ #
from os import path as _p

if not _p.exists("/root/.ipython/rlab_utils.py"):
    from shlex import split as _spl
    from subprocess import run

    shellCmd = "wget -qq https://biplobsd.github.io/RLabClone/res/rlab_utils.py \
                    -O /root/.ipython/rlab_utils.py"
    run(_spl(shellCmd))

from datetime import datetime as _dt
from rlab_utils import (
    displayOutput,
    checkAvailable,
    runSh,
    prepareSession,
    PATH_RClone_Config,
    accessSettingFile,
    memGiB,
)


def populateActionArg():
    if Mode == "Copy":
        actionArg = "copy"
    elif Mode == "Sync":
        actionArg = "sync"
    elif Mode == "Verify":
        actionArg = "check"
    elif Mode == "Dedupe":
        actionArg = "dedupe largest"
    elif Mode == "Clean Empty Dirs":
        actionArg = "rmdirs"
    elif Mode == "Empty Trash":
        actionArg = "delete"
    else:
        actionArg = "move"

    return actionArg


def populateCompareArg():
    if Compare == "Mod-Time":
        compareArg = "--ignore-size"
    elif Compare == "Size":
        compareArg = "--size-only"
    elif Compare == "Checksum":
        compareArg = "-c --ignore-size"
    else:
        compareArg = "-c"

    return compareArg


def populateOptimizeGDriveArg():
    return (
        "--buffer-size 256M \
            --drive-chunk-size 256M \
                --drive-upload-cutoff 256M \
                    --drive-acknowledge-abuse \
                        --drive-keep-revision-forever"
        if OPTIMIZE_GDRIVE
        else "--buffer-size 128M"
    )


def populateGDriveCopyArg():
    if BRIDGE_TRANSFER and memGiB() < 13:
        global TRANSFERS, CHECKERS
        TRANSFERS, CHECKERS = 10, 80
    else:
        pass
    return "--disable copy" if BRIDGE_TRANSFER else "--drive-server-side-across-configs"


def populateStatsArg():
    statsArg = "--stats-one-line --stats=5s" if SIMPLE_LOG else "--stats=5s -P"
    if LOG_LEVEL != "OFF":
        statsArg += " -v" if SIMPLE_LOG else "-vv"
    elif LOG_LEVEL == "INFO":
        statsArg += " --log-level INFO"
    elif LOG_LEVEL == "ERROR":
        statsArg += " --log-level ERROR"
    else:
        statsArg += " --log-level DEBUG"
    return statsArg


def populateSyncModeArg():
    if Mode != "Sync":
        return ""
    elif SYNC_MODE == "Delete before transfering":
        syncModeArg = "--delete-before"
    elif SYNC_MODE == "Delete after transfering":
        syncModeArg = "--delete-after"
    else:
        syncModeArg = "--delete-during"
    if SYNC_TRACK_RENAME:
        syncModeArg += " --track-renames"
    return syncModeArg


def populateDedupeModeArg():
    if DEDUPE_MODE == "Interactive":
        dedupeModeArg = "--dedupe-mode interactive"
    elif DEDUPE_MODE == "Skip":
        dedupeModeArg = "--dedupe-mode skip"
    elif DEDUPE_MODE == "First":
        dedupeModeArg = "--dedupe-mode first"
    elif DEDUPE_MODE == "Newest":
        dedupeModeArg = "--dedupe-mode newest"
    elif DEDUPE_MODE == "Oldest":
        dedupeModeArg = "--dedupe-mode oldest"
    elif DEDUPE_MODE == "Rename":
        dedupeModeArg = "--dedupe-mode rename"
    else:
        dedupeModeArg = "--dedupe-mode largest"

    return dedupeModeArg


def generateCmd():
    sharedFilesArgs = (
        "--drive-shared-with-me --files-from /content/upload.txt --no-traverse"
        if COPY_SHARED_FILES
        else ""
    )

    logFileArg = f"--log-file /content/rclone_log.txt -vv -P"

    args = [
        "rclone",
        f"--config /root/.config/rclone/rclone.conf",
        '--user-agent "Mozilla"',
        populateActionArg(),
        f'"{Source}"',
        f'"{Destination}"' if Mode in ("Move", "Copy", "Sync") else "",
        f"--transfers {str(TRANSFERS)}",
        f"--checkers {str(CHECKERS)}",
    ]

    if Mode == "Verify":
        args.append("--one-way")
    elif Mode == "Empty Trash":
        args.append("--drive-trashed-only --drive-use-trash=false")
    else:
        args.extend(
            [
                populateGDriveCopyArg(),
                populateSyncModeArg(),
                populateCompareArg(),
                populateOptimizeGDriveArg(),
                "-u" if SKIP_NEWER_FILE else "",
                "--ignore-existing" if SKIP_EXISTED else "",
                "--no-update-modtime" if SKIP_UPDATE_MODTIME else "",
                "--one-file-system" if ONE_FILE_SYSTEM else "",
                "--tpslimit 95 --tpslimit-burst 40" if THROTTLE_TPS else "",
                "--fast-list" if FAST_LIST else "",
                "--delete-empty-src-dirs" if Mode == "Move" else "",
            ]
        )
    args.extend(
        [
            "-n" if DRY_RUN else "",
            populateStatsArg() if not RECORD_LOGFILE else logFileArg,
            sharedFilesArgs,
            Extra_Arguments,
        ]
    )

    return args


def executeRclone():
    prepareSession()
    if Source.strip() == "":
        displayOutput("❌ The Source field is empty.")
        return
    if checkAvailable("/content/rclone_log.txt"):
        if not checkAvailable("/content/logfiles"):
            runSh("mkdir -p -m 666 /content/logfiles")
        job = accessSettingFile("job.txt")
        runSh(
            f'mv /content/rclone_log.txt /content/logfiles/{job["title"]}_{job["status"]}_logfile.txt'
        )

    onGoingJob = {
        "title": f'{Mode}_{Source}_{Destination}_{_dt.now().strftime("%a-%H-%M-%S")}',
        "status": "ongoing",
    }
    accessSettingFile("job.txt", onGoingJob)

    cmd = " ".join(generateCmd())
    runSh(cmd, output=True)
    displayOutput(Mode, "success")

    onGoingJob["status"] = "finished"
    accessSettingFile("job.txt", onGoingJob)

executeRclone()
# Out:
# 2024/07/23 13:40:06 INFO  : Starting transaction limiter: max 95 transactions/s with burst 40
# 2024/07/23 13:40:11 INFO  : Google drive root 'sbackup': Making map for --track-renames
# 2024/07/23 13:40:11 INFO  : Google drive root 'sbackup': Finished making map for --track-renames
# 2024/07/23 13:40:14 INFO  :           0 B / 46.525 GiB, 0%, 0 B/s, ETA - (xfr#0/968)
# 2024/07/23 13:40:19 INFO  :   279.894 MiB / 46.525 GiB, 1%, 35.556 MiB/s, ETA 22m12s (xfr#0/968)
# 2024/07/23 13:40:22 INFO  : Book 04 - Soul Gem Collector 4/Cover.jpg: Copied (new)
# 2024/07/23 13:40:24 INFO  :   845.541 MiB / 46.525 GiB, 2%, 67.474 MiB/s, ETA 11m33s (xfr#1/968)
# 2024/07/23 13:40:25 INFO  : Book 02 - Monster Girl Base 2/Cover.jpg: Copied (new)
# 2024/07/23 13:40:29 INFO  :     1.361 GiB / 46.525 GiB, 3%, 80.232 MiB/s, ETA 9m36s (xfr#2/968)
# 2024/07/23 13:40:30 INFO  : Book 1 - Dragon Conjurer/Cover.jpg: Copied (new)
# 2024/07/23 13:40:32 INFO  : The Bastard 2.mp3: Copied (new)
# 2024/07/23 13:40:34 INFO  :     1.889 GiB / 46.301 GiB, 4%, 88.137 MiB/s, ETA 8m35s (xfr#4/968)
# 2024/07/23 13:40:37 INFO  : Gun Mage 3.mp3: Copied (new)
# 2024/07/23 13:40:38 INFO  : Conquering a Bloodthirsty Earth Vampire Lord, Book 3/Conquering a Bloodthirsty Earth Vampire Lord, Book 3.jpg: Copied (new)
# 2024/07/23 13:40:39 INFO  :     2.443 GiB / 46.255 GiB, 5%, 94.847 MiB/s, ETA 7m53s (xfr#6/968)
# 2024/07/23 13:40:44 INFO  :     2.981 GiB / 46.525 GiB, 6%, 99.143 MiB/s, ETA 7m29s (xfr#6/968)
# 2024/07/23 13:40:44 INFO  : Book 05 - Arena 5/Cover.jpg: Copied (new)
# 2024/07/23 13:40:47 INFO  : Book 02 - Monster Girl Base 2/Logan Jacobs - Monster Girl Base 2.mp3: Copied (new)
# 2024/07/23 13:40:49 INFO  : Book 04 - Soul Gem Collector 4/Logan Jacobs - Soul Gem Collector 4.mp3: Copied (new)
# 2024/07/23 13:40:49 INFO  :     3.504 GiB / 45.860 GiB, 8%, 101.439 MiB/s, ETA 7m7s (xfr#9/968)
# 2024/07/23 13:40:51 INFO  : Divine Collector/Divine Collector.cue: Copied (new)
# 2024/07/23 13:40:53 INFO  : Divine Collector/Divine Collector.jpg: Copied (new)
# 2024/07/23 13:40:53 INFO  : Blood Mage 2 - Logan Jacobs.mp3: Copied (new)
# 2024/07/23 13:40:54 INFO  :     4.047 GiB / 46.525 GiB, 9%, 103.607 MiB/s, ETA 6m59s (xfr#12/968)
# 2024/07/23 13:40:57 INFO  : Divine Collector/Divine Collector_.jpg: Copied (new)
# 2024/07/23 13:40:57 INFO  : Dragon Emperor 10.mp3: Copied (new)
# 2024/07/23 13:40:59 INFO  : Vampire Lord 2.mp3: Copied (new)
# 2024/07/23 13:40:59 INFO  :     4.576 GiB / 46.525 GiB, 10%, 105.407 MiB/s, ETA 6m47s (xfr#15/968)
# 2024/07/23 13:41:00 INFO  : Bastard 3.mp3: Copied (new)
# 2024/07/23 13:41:00 INFO  : Divine Collector 2/Divine Collector 2.cue: Copied (new)
# 2024/07/23 13:41:01 INFO  : Divine Collector 2/Divine Collector 2.jpg: Copied (new)
# 2024/07/23 13:41:02 INFO  : Divine Collector 2/Divine Collector 2.nfo: Copied (new)
# 2024/07/23 13:41:04 INFO  :     5.097 GiB / 46.525 GiB, 11%, 105.688 MiB/s, ETA 6m41s (xfr#19/968)
# 2024/07/23 13:41:04 INFO  : Divine Collector 2/Divine Collector 2_.jpg: Copied (new)
# 2024/07/23 13:41:05 INFO  : Book 1 - Dragon Conjurer/Éric Vall - Dragon Conjurer.mp3: Copied (new)
# 2024/07/23 13:41:06 INFO  : Soul Gem Collector 2.m4b: Copied (new)
# 2024/07/23 13:41:06 INFO  : Book 05 - Arena 5/Logan Jacobs - Arena 5.mp3: Copied (new)
# 2024/07/23 13:41:07 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (01 of 18).mp3: Copied (new)
# 2024/07/23 13:41:07 INFO  : Book 03 - Monster Girl Base 3/Cover.jpg: Copied (new)
# 2024/07/23 13:41:08 INFO  : 1. Logan Jacobs - Vampire Lord.mp3: Copied (new)
# 2024/07/23 13:41:09 INFO  :     5.618 GiB / 46.470 GiB, 12%, 105.721 MiB/s, ETA 6m35s (xfr#26/968)
# 2024/07/23 13:41:09 INFO  : SuccubusLord 16.mp3: Copied (new)
# 2024/07/23 13:41:09 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (02 of 18).mp3: Copied (new)
# 2024/07/23 13:41:10 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (03 of 18).mp3: Copied (new)
# 2024/07/23 13:41:11 INFO  : Conquering a Bloodthirsty Earth Vampire Lord, Book 3/Conquering a Bloodthirsty Earth Vampire Lord, Book 3.mp3: Copied (new)
# 2024/07/23 13:41:13 INFO  : Logan Jacobs - Soul Collector 3.mp3: Copied (new)
# 2024/07/23 13:41:13 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (06 of 18).mp3: Copied (new)
# 2024/07/23 13:41:14 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (04 of 18).mp3: Copied (new)
# 2024/07/23 13:41:14 INFO  :     6.171 GiB / 46.474 GiB, 13%, 107.577 MiB/s, ETA 6m23s (xfr#33/968)
# 2024/07/23 13:41:14 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (07 of 18).mp3: Copied (new)
# 2024/07/23 13:41:14 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (05 of 18).mp3: Copied (new)
# 2024/07/23 13:41:14 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (08 of 18).mp3: Copied (new)
# 2024/07/23 13:41:15 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (10 of 18).mp3: Copied (new)
# 2024/07/23 13:41:16 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (09 of 18).mp3: Copied (new)
# 2024/07/23 13:41:16 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (11 of 18).mp3: Copied (new)
# 2024/07/23 13:41:18 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (14 of 18).mp3: Copied (new)
# 2024/07/23 13:41:18 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (13 of 18).mp3: Copied (new)
# 2024/07/23 13:41:19 INFO  :     6.696 GiB / 46.483 GiB, 14%, 107.759 MiB/s, ETA 6m18s (xfr#41/968)
# 2024/07/23 13:41:20 INFO  : Soul_Gem_Collector.mp3: Copied (new)
# 2024/07/23 13:41:21 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (12 of 18).mp3: Copied (new)
# 2024/07/23 13:41:24 INFO  :     7.260 GiB / 46.525 GiB, 16%, 109.971 MiB/s, ETA 6m5s (xfr#43/968)
# 2024/07/23 13:41:25 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (18 of 18).mp3: Copied (new)
# 2024/07/23 13:41:25 INFO  : Dragon Emperor 11 by Eric Vall/01 - Intro.mp3: Copied (new)
# 2024/07/23 13:41:26 INFO  : Dragon Emperor 11 by Eric Vall/02 - Chapter One.mp3: Copied (new)
# 2024/07/23 13:41:26 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (16 of 18).mp3: Copied (new)
# 2024/07/23 13:41:27 INFO  : GunMage_ep7.mp3: Copied (new)
# 2024/07/23 13:41:27 INFO  : Dragon Emperor 11 by Eric Vall/06 - Chapter Five.mp3: Copied (new)
# 2024/07/23 13:41:28 INFO  : Dragon Emperor 11 by Eric Vall/03 - Chapter Two.mp3: Copied (new)
# 2024/07/23 13:41:28 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (15 of 18).mp3: Copied (new)
# 2024/07/23 13:41:29 INFO  :     7.792 GiB / 46.469 GiB, 17%, 109.756 MiB/s, ETA 6m (xfr#51/968)
# 2024/07/23 13:41:29 INFO  : Book 03 - Monster Girl Base 3/Logan Jacobs - Monster Girl Base 3 (17 of 18).mp3: Copied (new)
# 2024/07/23 13:41:29 INFO  : Dragon Emperor 11 by Eric Vall/04 - Chapter Three.mp3: Copied (new)
# 2024/07/23 13:41:30 INFO  : Dragon Emperor 11 by Eric Vall/05 - Chapter Four.mp3: Copied (new)
# 2024/07/23 13:41:31 INFO  : Dragon Emperor 11 by Eric Vall/08 - Chapter Seven.mp3: Copied (new)
# 2024/07/23 13:41:33 INFO  : Dragon Emperor 11 by Eric Vall/09 - Chapter Eight.mp3: Copied (new)
# 2024/07/23 13:41:33 INFO  : Dragon Emperor 11 by Eric Vall/07 - Chapter Six.mp3: Copied (new)
# 2024/07/23 13:41:34 INFO  :     8.325 GiB / 46.524 GiB, 18%, 109.728 MiB/s, ETA 5m56s (xfr#57/968)
# 2024/07/23 13:41:34 INFO  : Arena, Book 2.m4b: Copied (new)
# 2024/07/23 13:41:34 INFO  : Dragon Emperor 11 by Eric Vall/11 - Chapter Ten.mp3: Copied (new)
# 2024/07/23 13:41:35 INFO  : Dragon Emperor 11 by Eric Vall/10 - Chapter Nine.mp3: Copied (new)
# 2024/07/23 13:41:35 INFO  : Dragon Emperor 11 by Eric Vall/17 - Outro.mp3: Copied (new)
# 2024/07/23 13:41:37 INFO  : Dragon Emperor 11 by Eric Vall/12 - Chapter Eleven.mp3: Copied (new)
# 2024/07/23 13:41:37 INFO  : DragonEmperor4HumantoDragontoGod_ep7.mp3: Copied (new)
# 2024/07/23 13:41:38 INFO  : Dragon Emperor 11 by Eric Vall/Dragon Emperor 11 by Eric Vall.epub: Copied (new)
# 2024/07/23 13:41:38 INFO  : Dragon Emperor 11 by Eric Vall/15 - Chapter Fourteen.mp3: Copied (new)
# 2024/07/23 13:41:38 INFO  : Dragon Emperor 11 by Eric Vall/14 - Chapter Thirteen.mp3: Copied (new)
# 2024/07/23 13:41:38 INFO  : Dragon Emperor 11 by Eric Vall/16 - Chapter Fifteen.mp3: Copied (new)
# 2024/07/23 13:41:38 INFO  : BloodMage3_ep7.mp3: Copied (new)
# 2024/07/23 13:41:39 INFO  :     8.853 GiB / 46.424 GiB, 19%, 109.307 MiB/s, ETA 5m51s (xfr#68/968)
# 2024/07/23 13:41:39 INFO  : Dragon Emperor 11 by Eric Vall/Dragon Emperor 11 by Eric Vall.jpg: Copied (new)
# 2024/07/23 13:41:39 INFO  : Dragon Conjurer 4 - Eric Vall/001 Eric Vall - Dragon Conjurer 4 - Opening Credits.mp3: Copied (new)
# 2024/07/23 13:41:40 INFO  : Dragon Emperor 11 by Eric Vall/13 - Chapter Twelve.mp3: Copied (new)
# 2024/07/23 13:41:40 INFO  : 1-5/Wizardoms Rise of a Wizard Queen Fate of Wizardoms, Book 5 A.mp3: Copied (new)
# 2024/07/23 13:41:41 INFO  : 1-5/Wizardoms Objects of Power Fate of Wizardoms, Book 4 Audiobo.mp3: Copied (new)
# 2024/07/23 13:41:42 INFO  : Dragon Conjurer 4 - Eric Vall/002 Eric Vall - Dragon Conjurer 4 - Chapter 1.mp3: Copied (new)
# 2024/07/23 13:41:43 INFO  : Dragon Conjurer 4 - Eric Vall/003 Eric Vall - Dragon Conjurer 4 - Chapter 2.mp3: Copied (new)
# 2024/07/23 13:41:43 INFO  : Dragon Conjurer 4 - Eric Vall/005 Eric Vall - Dragon Conjurer 4 - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:41:44 INFO  :     9.409 GiB / 46.523 GiB, 20%, 110.380 MiB/s, ETA 5m44s (xfr#76/968)
# 2024/07/23 13:41:44 INFO  : Dragon Conjurer 4 - Eric Vall/004 Eric Vall - Dragon Conjurer 4 - Chapter 3.mp3: Copied (new)
# 2024/07/23 13:41:44 INFO  : Dragon Conjurer 4 - Eric Vall/006 Eric Vall - Dragon Conjurer 4 - Chapter 5.mp3: Copied (new)
# 2024/07/23 13:41:44 INFO  : Dragon Conjurer 4 - Eric Vall/008 Eric Vall - Dragon Conjurer 4 - Chapter 7.mp3: Copied (new)
# 2024/07/23 13:41:45 INFO  : Dragon Conjurer 4 - Eric Vall/012 Eric Vall - Dragon Conjurer 4 - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:41:45 INFO  : Dragon Conjurer 4 - Eric Vall/010 Eric Vall - Dragon Conjurer 4 - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:41:46 INFO  : Dragon Conjurer 4 - Eric Vall/015 Eric Vall - Dragon Conjurer 4 - Chapter 14.mp3: Copied (new)
# 2024/07/23 13:41:47 INFO  : Dragon Conjurer 4 - Eric Vall/013 Eric Vall - Dragon Conjurer 4 - Chapter 12.mp3: Copied (new)
# 2024/07/23 13:41:47 INFO  : Divine Collector 2/Divine Collector 2.m4b: Copied (new)
# 2024/07/23 13:41:47 INFO  : Dragon Conjurer 4 - Eric Vall/018 Eric Vall - Dragon Conjurer 4 - End Credits.mp3: Copied (new)
# 2024/07/23 13:41:47 INFO  : Dragon Conjurer 4 - Eric Vall/007 Eric Vall - Dragon Conjurer 4 - Chapter 6.mp3: Copied (new)
# 2024/07/23 13:41:48 INFO  : Dragon Conjurer 4 - Eric Vall/019 Eric Vall - Dragon Conjurer 4 - Outro.mp3: Copied (new)
# 2024/07/23 13:41:48 INFO  : Dragon Conjurer 4 - Eric Vall/009 Eric Vall - Dragon Conjurer 4 - Chapter 8.mp3: Copied (new)
# 2024/07/23 13:41:48 INFO  : Dragon Conjurer 4 - Eric Vall/016 Eric Vall - Dragon Conjurer 4 - Chapter 15.mp3: Copied (new)
# 2024/07/23 13:41:49 INFO  :     9.920 GiB / 46.438 GiB, 21%, 109.130 MiB/s, ETA 5m42s (xfr#89/968)
# 2024/07/23 13:41:49 INFO  : Dragon Conjurer 4 - Eric Vall/011 Eric Vall - Dragon Conjurer 4 - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:41:49 INFO  : Dragon Conjurer 4 - Eric Vall/017 Eric Vall - Dragon Conjurer 4 - Chapter 16.mp3: Copied (new)
# 2024/07/23 13:41:51 INFO  : Divine Collector 3/Divine Collector 3.cue: Copied (new)
# 2024/07/23 13:41:51 INFO  : Dragon Conjurer 4 - Eric Vall/014 Eric Vall - Dragon Conjurer 4 - Chapter 13.mp3: Copied (new)
# 2024/07/23 13:41:51 INFO  : Divine Collector 3/Divine Collector 3.nfo: Copied (new)
# 2024/07/23 13:41:51 INFO  : Dragon Conjurer 4 - Eric Vall/cover.jpg: Copied (new)
# 2024/07/23 13:41:52 INFO  : Divine Collector 3/Divine Collector 3.jpg: Copied (new)
# 2024/07/23 13:41:52 INFO  : Divine Collector 3/Divine Collector 3_.jpg: Copied (new)
# 2024/07/23 13:41:54 INFO  :    10.446 GiB / 46.467 GiB, 22%, 108.942 MiB/s, ETA 5m38s (xfr#97/968)
# 2024/07/23 13:41:54 INFO  : Alex in Haremland 2 - Logan Jacobs/002 Logan Jacobs - Alex in Haremland 2 - Introduction.mp3: Copied (new)
# 2024/07/23 13:41:54 INFO  : Alex in Haremland 2 - Logan Jacobs/001 Logan Jacobs - Alex in Haremland 2 - Opening Credits.mp3: Copied (new)
# 2024/07/23 13:41:55 INFO  : Alex in Haremland 2 - Logan Jacobs/003 Logan Jacobs - Alex in Haremland 2 - Chapter 1.mp3: Copied (new)
# 2024/07/23 13:41:55 INFO  : Alex in Haremland 2 - Logan Jacobs/004 Logan Jacobs - Alex in Haremland 2 - Chapter 2.mp3: Copied (new)
# 2024/07/23 13:41:55 INFO  : Divine Collector/Divine Collector.m4b: Copied (new)
# 2024/07/23 13:41:55 INFO  : Alex in Haremland 2 - Logan Jacobs/005 Logan Jacobs - Alex in Haremland 2 - Chapter 3.mp3: Copied (new)
# 2024/07/23 13:41:55 INFO  : Alex in Haremland 2 - Logan Jacobs/006 Logan Jacobs - Alex in Haremland 2 - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:41:56 INFO  : Alex in Haremland 2 - Logan Jacobs/009 Logan Jacobs - Alex in Haremland 2 - Chapter 7.mp3: Copied (new)
# 2024/07/23 13:41:56 INFO  : Alex in Haremland 2 - Logan Jacobs/008 Logan Jacobs - Alex in Haremland 2 - Chapter 6.mp3: Copied (new)
# 2024/07/23 13:41:57 INFO  : Alex in Haremland 2 - Logan Jacobs/007 Logan Jacobs - Alex in Haremland 2 - Chapter 5.mp3: Copied (new)
# 2024/07/23 13:41:57 INFO  : Alex in Haremland 2 - Logan Jacobs/011 Logan Jacobs - Alex in Haremland 2 - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:41:57 INFO  : Alex in Haremland 2 - Logan Jacobs/012 Logan Jacobs - Alex in Haremland 2 - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:41:58 INFO  : Alex in Haremland 2 - Logan Jacobs/013 Logan Jacobs - Alex in Haremland 2 - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:41:58 INFO  : Alex in Haremland 2 - Logan Jacobs/016 Logan Jacobs - Alex in Haremland 2 - Chapter 14.mp3: Copied (new)
# 2024/07/23 13:41:58 INFO  : Alex in Haremland 2 - Logan Jacobs/015 Logan Jacobs - Alex in Haremland 2 - Chapter 13.mp3: Copied (new)
# 2024/07/23 13:41:59 INFO  :    10.922 GiB / 46.428 GiB, 24%, 107.023 MiB/s, ETA 5m39s (xfr#112/968)
# 2024/07/23 13:41:59 INFO  : Alex in Haremland 2 - Logan Jacobs/014 Logan Jacobs - Alex in Haremland 2 - Chapter 12.mp3: Copied (new)
# 2024/07/23 13:41:59 INFO  : Alex in Haremland 2 - Logan Jacobs/021 Logan Jacobs - Alex in Haremland 2 - End Credits.mp3: Copied (new)
# 2024/07/23 13:41:59 INFO  : Alex in Haremland 2 - Logan Jacobs/020 Logan Jacobs - Alex in Haremland 2 - Outro.mp3: Copied (new)
# 2024/07/23 13:42:00 INFO  : Alex in Haremland 2 - Logan Jacobs/010 Logan Jacobs - Alex in Haremland 2 - Chapter 8.mp3: Copied (new)
# 2024/07/23 13:42:00 INFO  : Alex in Haremland 2 - Logan Jacobs/018 Logan Jacobs - Alex in Haremland 2 - Chapter 16.mp3: Copied (new)
# 2024/07/23 13:42:02 INFO  : Alex in Haremland 2 - Logan Jacobs/017 Logan Jacobs - Alex in Haremland 2 - Chapter 15.mp3: Copied (new)
# 2024/07/23 13:42:03 INFO  : Alex in Haremland 2 - Logan Jacobs/019 Logan Jacobs - Alex in Haremland 2 - Chapter 17.mp3: Copied (new)
# 2024/07/23 13:42:04 INFO  :    11.402 GiB / 46.497 GiB, 25%, 103.329 MiB/s, ETA 5m47s (xfr#119/968)
# 2024/07/23 13:42:05 INFO  : Backyard Dungeon - Logan Jacobs/001 Logan Jacobs - Backyard Dungeon - Opening Credits.mp3: Copied (new)
# 2024/07/23 13:42:06 INFO  : Alex in Haremland 2 - Logan Jacobs/cover.jpg: Copied (new)
# 2024/07/23 13:42:06 INFO  : Book 01 - Monster Girl Base/Cover.jpg: Copied (new)
# 2024/07/23 13:42:06 INFO  : Backyard Dungeon - Logan Jacobs/002 Logan Jacobs - Backyard Dungeon - Chapter 1.mp3: Copied (new)
# 2024/07/23 13:42:06 INFO  : Backyard Dungeon - Logan Jacobs/006 Logan Jacobs - Backyard Dungeon - Chapter 5.mp3: Copied (new)
# 2024/07/23 13:42:07 INFO  : Backyard Dungeon - Logan Jacobs/010 Logan Jacobs - Backyard Dungeon - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:42:07 INFO  : Backyard Dungeon - Logan Jacobs/004 Logan Jacobs - Backyard Dungeon - Chapter 3.mp3: Copied (new)
# 2024/07/23 13:42:07 INFO  : Backyard Dungeon - Logan Jacobs/007 Logan Jacobs - Backyard Dungeon - Chapter 6.mp3: Copied (new)
# 2024/07/23 13:42:07 INFO  : Backyard Dungeon - Logan Jacobs/011 Logan Jacobs - Backyard Dungeon - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:42:07 INFO  : Backyard Dungeon - Logan Jacobs/008 Logan Jacobs - Backyard Dungeon - Chapter 7.mp3: Copied (new)
# 2024/07/23 13:42:08 INFO  : Backyard Dungeon - Logan Jacobs/003 Logan Jacobs - Backyard Dungeon - Chapter 2.mp3: Copied (new)
# 2024/07/23 13:42:08 INFO  : Backyard Dungeon - Logan Jacobs/005 Logan Jacobs - Backyard Dungeon - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:42:08 INFO  : Backyard Dungeon - Logan Jacobs/009 Logan Jacobs - Backyard Dungeon - Chapter 8.mp3: Copied (new)
# 2024/07/23 13:42:08 INFO  : Backyard Dungeon - Logan Jacobs/012 Logan Jacobs - Backyard Dungeon - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:42:08 INFO  : Backyard Dungeon - Logan Jacobs/013 Logan Jacobs - Backyard Dungeon - Chapter 12.mp3: Copied (new)
# 2024/07/23 13:42:08 INFO  : Book 01 - Monster Girl Base/Logan Jacobs - Monster Girl Base.mp3: Copied (new)
# 2024/07/23 13:42:09 INFO  :    11.722 GiB / 46.330 GiB, 25%, 94.166 MiB/s, ETA 6m16s (xfr#135/968)
# 2024/07/23 13:42:09 INFO  : Backyard Dungeon - Logan Jacobs/014 Logan Jacobs - Backyard Dungeon - Chapter 13.mp3: Copied (new)
# 2024/07/23 13:42:10 INFO  : Backyard Dungeon - Logan Jacobs/017 Logan Jacobs - Backyard Dungeon - End Credits.mp3: Copied (new)
# 2024/07/23 13:42:10 INFO  : RRR 2022 Hindi 720p NF WEBRip AAC 5.1 ESubs x264 - mkvAnime.mkv: Copied (new)
# 2024/07/23 13:42:11 INFO  : Backyard Dungeon - Logan Jacobs/cover.jpg: Copied (new)
# 2024/07/23 13:42:13 INFO  : Dragon Conjurer 5 - Eric Vall/001 Eric Vall - Dragon Conjurer 5 - Opening Credits.mp3: Copied (new)
# 2024/07/23 13:42:14 INFO  : Dragon Conjurer 5 - Eric Vall/009 Eric Vall - Dragon Conjurer 5 - Chapter 8.mp3: Copied (new)
# 2024/07/23 13:42:14 INFO  :    12.052 GiB / 46.509 GiB, 26%, 86.662 MiB/s, ETA 6m47s (xfr#141/968)
# 2024/07/23 13:42:14 INFO  : Dragon Conjurer 5 - Eric Vall/002 Eric Vall - Dragon Conjurer 5 - Chapter 1.mp3: Copied (new)
# 2024/07/23 13:42:14 INFO  : Backyard Dungeon - Logan Jacobs/016 Logan Jacobs - Backyard Dungeon - Chapter 15.mp3: Copied (new)
# 2024/07/23 13:42:14 INFO  : Dragon Conjurer 5 - Eric Vall/011 Eric Vall - Dragon Conjurer 5 - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:42:14 INFO  : Dragon Conjurer 5 - Eric Vall/007 Eric Vall - Dragon Conjurer 5 - Chapter 6.mp3: Copied (new)
# 2024/07/23 13:42:14 INFO  : Dragon Conjurer 5 - Eric Vall/005 Eric Vall - Dragon Conjurer 5 - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:42:14 INFO  : Dragon Conjurer 5 - Eric Vall/003 Eric Vall - Dragon Conjurer 5 - Chapter 2.mp3: Copied (new)
# 2024/07/23 13:42:15 INFO  : Dragon Conjurer 5 - Eric Vall/012 Eric Vall - Dragon Conjurer 5 - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:42:15 INFO  : Dragon Conjurer 5 - Eric Vall/008 Eric Vall - Dragon Conjurer 5 - Chapter 7.mp3: Copied (new)
# 2024/07/23 13:42:15 INFO  : Dragon Conjurer 5 - Eric Vall/004 Eric Vall - Dragon Conjurer 5 - Chapter 3.mp3: Copied (new)
# 2024/07/23 13:42:15 INFO  : Dragon Conjurer 5 - Eric Vall/010 Eric Vall - Dragon Conjurer 5 - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:42:15 INFO  : Dragon Conjurer 5 - Eric Vall/006 Eric Vall - Dragon Conjurer 5 - Chapter 5.mp3: Copied (new)
# 2024/07/23 13:42:15 INFO  : Backyard Dungeon - Logan Jacobs/015 Logan Jacobs - Backyard Dungeon - Chapter 14.mp3: Copied (new)
# 2024/07/23 13:42:15 INFO  : Dragon Conjurer 5 - Eric Vall/013 Eric Vall - Dragon Conjurer 5 - Chapter 12.mp3: Copied (new)
# 2024/07/23 13:42:16 INFO  : Dragon Conjurer 5 - Eric Vall/014 Eric Vall - Dragon Conjurer 5 - Chapter 13.mp3: Copied (new)
# 2024/07/23 13:42:17 INFO  : Dragon Conjurer 5 - Eric Vall/015 Eric Vall - Dragon Conjurer 5 - Chapter 14.mp3: Copied (new)
# 2024/07/23 13:42:17 INFO  : Dragon Conjurer 5 - Eric Vall/016 Eric Vall - Dragon Conjurer 5 - Chapter 15.mp3: Copied (new)
# 2024/07/23 13:42:18 INFO  : Dragon Conjurer 5 - Eric Vall/017 Eric Vall - Dragon Conjurer 5 - Chapter 16.mp3: Copied (new)
# 2024/07/23 13:42:19 INFO  : Dragon Conjurer 5 - Eric Vall/018 Eric Vall - Dragon Conjurer 5 - End Credits.mp3: Copied (new)
# 2024/07/23 13:42:19 INFO  :    12.162 GiB / 46.461 GiB, 26%, 68.192 MiB/s, ETA 8m35s (xfr#159/968)
# 2024/07/23 13:42:21 INFO  : Alex in Haremland/01 - Opening Credits.mp3: Copied (new)
# 2024/07/23 13:42:21 INFO  : Alex in Haremland/03 - Chapter 2.mp3: Copied (new)
# 2024/07/23 13:42:21 INFO  : Alex in Haremland/11 - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:42:21 INFO  : Dragon Conjurer 5 - Eric Vall/019 Eric Vall - Dragon Conjurer 5 - Outro.mp3: Copied (new)
# 2024/07/23 13:42:22 INFO  : Alex in Haremland/04 - Chapter 3.mp3: Copied (new)
# 2024/07/23 13:42:22 INFO  : Dragon Conjurer 5 - Eric Vall/cover.jpg: Copied (new)
# 2024/07/23 13:42:22 INFO  : Alex in Haremland/05 - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:42:22 INFO  : Alex in Haremland/02 - Chapter 1.mp3: Copied (new)
# 2024/07/23 13:42:22 INFO  : Alex in Haremland/06 - Chapter 5.mp3: Copied (new)
# 2024/07/23 13:42:22 INFO  : Alex in Haremland/10 - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:42:23 INFO  : Alex in Haremland/12 - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:42:23 INFO  : Alex in Haremland/14 - Chapter 13.mp3: Copied (new)
# 2024/07/23 13:42:23 INFO  : Alex in Haremland/07 - Chapter 6.mp3: Copied (new)
# 2024/07/23 13:42:23 INFO  : Alex in Haremland/08 - Chapter 7.mp3: Copied (new)
# 2024/07/23 13:42:23 INFO  : Alex in Haremland/13 - Chapter 12.mp3: Copied (new)
# 2024/07/23 13:42:24 INFO  :    12.454 GiB / 46.402 GiB, 27%, 66.012 MiB/s, ETA 8m46s (xfr#174/968)
# 2024/07/23 13:42:24 INFO  : Alex in Haremland/09 - Chapter 8.mp3: Copied (new)
# 2024/07/23 13:42:24 INFO  : Alex in Haremland/15 - Chapter 14.mp3: Copied (new)
# 2024/07/23 13:42:24 INFO  : 1-5/Fate of Wizardoms Boxed Set An Epic Fantasy Series1-3 Wizardoms.mp3: Copied (new)
# 2024/07/23 13:42:25 INFO  : Alex in Haremland/20 - End Credits.mp3: Copied (new)
# 2024/07/23 13:42:25 INFO  : Alex in Haremland/21 - Outro.mp3: Copied (new)
# 2024/07/23 13:42:27 INFO  : Alex in Haremland/16 - Chapter 15.mp3: Copied (new)
# 2024/07/23 13:42:28 INFO  : Backyard Dungeon 2 - Logan Jacobs/001 Logan Jacobs - Backyard Dungeon 2 - Opening Credits.mp3: Copied (new)
# 2024/07/23 13:42:28 INFO  : Backyard Dungeon 2 - Logan Jacobs/008 Logan Jacobs - Backyard Dungeon 2 - Chapter 7.mp3: Copied (new)
# 2024/07/23 13:42:29 INFO  : Alex in Haremland/17 - Chapter 16.mp3: Copied (new)
# 2024/07/23 13:42:29 INFO  :    12.752 GiB / 46.465 GiB, 27%, 64.794 MiB/s, ETA 8m52s (xfr#183/968)
# 2024/07/23 13:42:29 INFO  : Alex in Haremland/19 - Chapter 18.mp3: Copied (new)
# 2024/07/23 13:42:29 INFO  : Alex in Haremland/Alex in Haremland.jpg: Copied (new)
# 2024/07/23 13:42:29 INFO  : Backyard Dungeon 2 - Logan Jacobs/005 Logan Jacobs - Backyard Dungeon 2 - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:42:29 INFO  : Alex in Haremland/18 - Chapter 17.mp3: Copied (new)
# 2024/07/23 13:42:29 INFO  : Backyard Dungeon 2 - Logan Jacobs/002 Logan Jacobs - Backyard Dungeon 2 - Chapter 1.mp3: Copied (new)
# 2024/07/23 13:42:29 INFO  : Backyard Dungeon 2 - Logan Jacobs/009 Logan Jacobs - Backyard Dungeon 2 - Chapter 8.mp3: Copied (new)
# 2024/07/23 13:42:29 INFO  : Backyard Dungeon 2 - Logan Jacobs/007 Logan Jacobs - Backyard Dungeon 2 - Chapter 6.mp3: Copied (new)
# 2024/07/23 13:42:29 INFO  : Backyard Dungeon 2 - Logan Jacobs/012 Logan Jacobs - Backyard Dungeon 2 - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:42:29 INFO  : Backyard Dungeon 2 - Logan Jacobs/006 Logan Jacobs - Backyard Dungeon 2 - Chapter 5.mp3: Copied (new)
# 2024/07/23 13:42:30 INFO  : Backyard Dungeon 2 - Logan Jacobs/010 Logan Jacobs - Backyard Dungeon 2 - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:42:30 INFO  : Backyard Dungeon 2 - Logan Jacobs/011 Logan Jacobs - Backyard Dungeon 2 - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:42:30 INFO  : Backyard Dungeon 2 - Logan Jacobs/004 Logan Jacobs - Backyard Dungeon 2 - Chapter 3.mp3: Copied (new)
# 2024/07/23 13:42:30 INFO  : Backyard Dungeon 2 - Logan Jacobs/003 Logan Jacobs - Backyard Dungeon 2 - Chapter 2.mp3: Copied (new)
# 2024/07/23 13:42:31 INFO  : Backyard Dungeon 2 - Logan Jacobs/013 Logan Jacobs - Backyard Dungeon 2 - Chapter 12.mp3: Copied (new)
# 2024/07/23 13:42:31 INFO  : Backyard Dungeon 2 - Logan Jacobs/014 Logan Jacobs - Backyard Dungeon 2 - Chapter 13.mp3: Copied (new)
# 2024/07/23 13:42:32 INFO  : Backyard Dungeon 2 - Logan Jacobs/015 Logan Jacobs - Backyard Dungeon 2 - Chapter 14.mp3: Copied (new)
# 2024/07/23 13:42:34 INFO  :    12.897 GiB / 46.512 GiB, 28%, 54.473 MiB/s, ETA 10m31s (xfr#199/968)
# 2024/07/23 13:42:35 INFO  : Backyard Dungeon 2 - Logan Jacobs/020 Logan Jacobs - Backyard Dungeon 2 - End Credits.mp3: Copied (new)
# 2024/07/23 13:42:35 INFO  : Dragon Emperor 13 by Eric Vall/01 - Intro.mp3: Copied (new)
# 2024/07/23 13:42:36 INFO  : Backyard Dungeon 2 - Logan Jacobs/018 Logan Jacobs - Backyard Dungeon 2 - Chapter 17.mp3: Copied (new)
# 2024/07/23 13:42:36 INFO  : Dragon Emperor 13 by Eric Vall/02 - Chapter One.mp3: Copied (new)
# 2024/07/23 13:42:36 INFO  : Backyard Dungeon 2 - Logan Jacobs/019 Logan Jacobs - Backyard Dungeon 2 - Chapter 18.mp3: Copied (new)
# 2024/07/23 13:42:36 INFO  : Dragon Emperor 13 by Eric Vall/06 - Chapter Five.mp3: Copied (new)
# 2024/07/23 13:42:36 INFO  : Dragon Emperor 13 by Eric Vall/10 - Chapter Nine.mp3: Copied (new)
# 2024/07/23 13:42:36 INFO  : Backyard Dungeon 2 - Logan Jacobs/017 Logan Jacobs - Backyard Dungeon 2 - Chapter 16.mp3: Copied (new)
# 2024/07/23 13:42:36 INFO  : Dragon Emperor 13 by Eric Vall/04 - Chapter Three.mp3: Copied (new)
# 2024/07/23 13:42:36 INFO  : Dragon Emperor 13 by Eric Vall/03 - Chapter Two.mp3: Copied (new)
# 2024/07/23 13:42:37 INFO  : Backyard Dungeon 2 - Logan Jacobs/cover.jpg: Copied (new)
# 2024/07/23 13:42:37 INFO  : Dragon Emperor 13 by Eric Vall/09 - Chapter Eight.mp3: Copied (new)
# 2024/07/23 13:42:37 INFO  : Dragon Emperor 13 by Eric Vall/08 - Chapter Seven.mp3: Copied (new)
# 2024/07/23 13:42:37 INFO  : Dragon Emperor 13 by Eric Vall/11 - Chapter Ten.mp3: Copied (new)
# 2024/07/23 13:42:37 INFO  : Dragon Emperor 13 by Eric Vall/12 - Chapter Eleven.mp3: Copied (new)
# 2024/07/23 13:42:37 INFO  : Backyard Dungeon 2 - Logan Jacobs/016 Logan Jacobs - Backyard Dungeon 2 - Chapter 15.mp3: Copied (new)
# 2024/07/23 13:42:37 INFO  : Dragon Emperor 13 by Eric Vall/07 - Chapter Six.mp3: Copied (new)
# 2024/07/23 13:42:37 INFO  : Dragon Emperor 13 by Eric Vall/05 - Chapter Four.mp3: Copied (new)
# 2024/07/23 13:42:38 INFO  : Divine Collector 3/Divine Collector 3.m4b: Copied (new)
# 2024/07/23 13:42:38 INFO  : Dragon Emperor 13 by Eric Vall/13 - Chapter Twelve.mp3: Copied (new)
# 2024/07/23 13:42:39 INFO  :    13.056 GiB / 46.394 GiB, 28%, 49.467 MiB/s, ETA 11m30s (xfr#219/968)
# 2024/07/23 13:42:40 INFO  : Dragon Emperor 13 by Eric Vall/14 - Chapter Thirteen.mp3: Copied (new)
# 2024/07/23 13:42:40 INFO  : Dragon Emperor 13 by Eric Vall/18 - Outro.mp3: Copied (new)
# 2024/07/23 13:42:42 INFO  : Dragon Emperor 12 by Eric Vall/01 - Intro.mp3: Copied (new)
# 2024/07/23 13:42:43 INFO  : Dragon Emperor 13 by Eric Vall/Dragon Emperor 13 by Eric Vall.epub: Copied (new)
# 2024/07/23 13:42:43 INFO  : Dragon Emperor 13 by Eric Vall/15 - Chapter Fourteen.mp3: Copied (new)
# 2024/07/23 13:42:43 INFO  : Dragon Emperor 13 by Eric Vall/Dragon Emperor 13 by Eric Vall.jpg: Copied (new)
# 2024/07/23 13:42:43 INFO  : Dragon Emperor 12 by Eric Vall/09 - Chapter Eight.mp3: Copied (new)
# 2024/07/23 13:42:43 INFO  : Dragon Emperor 12 by Eric Vall/08 - Chapter Seven.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 12 by Eric Vall/03 - Chapter Two.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 12 by Eric Vall/06 - Chapter Five.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 12 by Eric Vall/11 - Chapter Ten.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  :    13.285 GiB / 46.253 GiB, 29%, 49.088 MiB/s, ETA 11m27s (xfr#230/968)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 12 by Eric Vall/10 - Chapter Nine.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 12 by Eric Vall/02 - Chapter One.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 13 by Eric Vall/17 - Chapter Sixteen.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 12 by Eric Vall/04 - Chapter Three.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 13 by Eric Vall/16 - Chapter Fifteen.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 12 by Eric Vall/05 - Chapter Four.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 12 by Eric Vall/14 - Chapter Thirteen.mp3: Copied (new)
# 2024/07/23 13:42:44 INFO  : Dragon Emperor 12 by Eric Vall/07 - Chapter Six.mp3: Copied (new)
# 2024/07/23 13:42:45 INFO  : Dragon Emperor 12 by Eric Vall/12 - Chapter Eleven.mp3: Copied (new)
# 2024/07/23 13:42:45 INFO  : Dragon Emperor 12 by Eric Vall/16 - Chapter Fifteen.mp3: Copied (new)
# 2024/07/23 13:42:46 INFO  : Dragon Emperor 12 by Eric Vall/15 - Chapter Fourteen.mp3: Copied (new)
# 2024/07/23 13:42:47 INFO  : Dragon Emperor 12 by Eric Vall/18 - Outro.mp3: Copied (new)
# 2024/07/23 13:42:49 INFO  :    13.363 GiB / 46.509 GiB, 29%, 39.484 MiB/s, ETA 14m19s (xfr#242/968)
# 2024/07/23 13:42:49 INFO  : Dragon Emperor 12 by Eric Vall/Dragon Emperor 12 by Eric Vall.jpg: Copied (new)
# 2024/07/23 13:42:54 INFO  :    13.581 GiB / 46.525 GiB, 29%, 40.011 MiB/s, ETA 14m3s (xfr#243/968)
# 2024/07/23 13:42:56 INFO  : Dragon Emperor 12 by Eric Vall/Dragon Emperor 12 by Eric Vall.epub: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragons of Asgard 3 - Logan Jacobs/001 Logan Jacobs - Dragons of Asgard 3 - Opening Credits.mp3: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragon Emperor 12 by Eric Vall/17 - Chapter Sixteen.mp3: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragons of Asgard 3 - Logan Jacobs/008 Logan Jacobs - Dragons of Asgard 3 - Chapter 7.mp3: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragons of Asgard 3 - Logan Jacobs/003 Logan Jacobs - Dragons of Asgard 3 - Chapter 2.mp3: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragons of Asgard 3 - Logan Jacobs/002 Logan Jacobs - Dragons of Asgard 3 - Chapter 1.mp3: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragons of Asgard 3 - Logan Jacobs/006 Logan Jacobs - Dragons of Asgard 3 - Chapter 5.mp3: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragon Emperor 12 by Eric Vall/13 - Chapter Twelve.mp3: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragons of Asgard 3 - Logan Jacobs/005 Logan Jacobs - Dragons of Asgard 3 - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragons of Asgard 3 - Logan Jacobs/004 Logan Jacobs - Dragons of Asgard 3 - Chapter 3.mp3: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragons of Asgard 3 - Logan Jacobs/010 Logan Jacobs - Dragons of Asgard 3 - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:42:56 INFO  : Dragons of Asgard 3 - Logan Jacobs/012 Logan Jacobs - Dragons of Asgard 3 - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:42:57 INFO  : Dragons of Asgard 3 - Logan Jacobs/014 Logan Jacobs - Dragons of Asgard 3 - Chapter 13.mp3: Copied (new)
# 2024/07/23 13:42:57 INFO  : Dragons of Asgard 3 - Logan Jacobs/007 Logan Jacobs - Dragons of Asgard 3 - Chapter 6.mp3: Copied (new)
# 2024/07/23 13:42:57 INFO  : Dragons of Asgard 3 - Logan Jacobs/015 Logan Jacobs - Dragons of Asgard 3 - Chapter 14.mp3: Copied (new)
# 2024/07/23 13:42:57 INFO  : Dragons of Asgard 3 - Logan Jacobs/016 Logan Jacobs - Dragons of Asgard 3 - Chapter 15.mp3: Copied (new)
# 2024/07/23 13:42:57 INFO  : Dragons of Asgard 3 - Logan Jacobs/011 Logan Jacobs - Dragons of Asgard 3 - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:42:57 INFO  : Dragons of Asgard 3 - Logan Jacobs/013 Logan Jacobs - Dragons of Asgard 3 - Chapter 12.mp3: Copied (new)
# 2024/07/23 13:42:57 INFO  : Dragons of Asgard 3 - Logan Jacobs/009 Logan Jacobs - Dragons of Asgard 3 - Chapter 8.mp3: Copied (new)
# 2024/07/23 13:42:59 INFO  :    13.738 GiB / 46.422 GiB, 30%, 39.186 MiB/s, ETA 14m14s (xfr#262/968)
# 2024/07/23 13:43:00 INFO  : Eric Vall - Dragon Emperor - Book 9/Dragon Emperor - Book 9.mp4: Copied (new)
# 2024/07/23 13:43:02 INFO  : Dragons of Asgard 3 - Logan Jacobs/020 Logan Jacobs - Dragons of Asgard 3 - End Credits.mp3: Copied (new)
# 2024/07/23 13:43:03 INFO  : Eric Vall - Dragon Emperor 7 - Human to Dragon to God Dragon Emperor, Book 7/proxy-image.jpg: Copied (new)
# 2024/07/23 13:43:04 INFO  :    13.738 GiB / 46.496 GiB, 30%, 28.403 MiB/s, ETA 19m40s (xfr#265/968)
# 2024/07/23 13:43:09 INFO  :    14.023 GiB / 46.525 GiB, 30%, 35.325 MiB/s, ETA 15m42s (xfr#265/968)
# 2024/07/23 13:43:09 INFO  : Dragons of Asgard 3 - Logan Jacobs/021 Logan Jacobs - Dragons of Asgard 3 - Outro.mp3: Copied (new)
# 2024/07/23 13:43:09 INFO  : Eric Vall - Dragon Emperor 5/DragonEmperor5HumantoDragontoGod.cue: Copied (new)
# 2024/07/23 13:43:11 INFO  : Dragons of Asgard 2 - Logan Jacobs/001 Logan Jacobs - Dragons of Asgard 2 - Opening Credits.mp3: Copied (new)
# 2024/07/23 13:43:11 INFO  : Dragons of Asgard 3 - Logan Jacobs/018 Logan Jacobs - Dragons of Asgard 3 - Chapter 17.mp3: Copied (new)
# 2024/07/23 13:43:12 INFO  : Dragons of Asgard 3 - Logan Jacobs/017 Logan Jacobs - Dragons of Asgard 3 - Chapter 16.mp3: Copied (new)
# 2024/07/23 13:43:12 INFO  : Dragons of Asgard 2 - Logan Jacobs/003 Logan Jacobs - Dragons of Asgard 2 - Chapter 2.mp3: Copied (new)
# 2024/07/23 13:43:12 INFO  : Dragons of Asgard 2 - Logan Jacobs/005 Logan Jacobs - Dragons of Asgard 2 - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:43:12 INFO  : Dragons of Asgard 3 - Logan Jacobs/cover.jpg: Copied (new)
# 2024/07/23 13:43:12 INFO  : Dragons of Asgard 3 - Logan Jacobs/019 Logan Jacobs - Dragons of Asgard 3 - Chapter 18.mp3: Copied (new)
# 2024/07/23 13:43:12 INFO  : Dragons of Asgard 2 - Logan Jacobs/002 Logan Jacobs - Dragons of Asgard 2 - Chapter 1.mp3: Copied (new)
# 2024/07/23 13:43:12 INFO  : Dragons of Asgard 2 - Logan Jacobs/011 Logan Jacobs - Dragons of Asgard 2 - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:43:12 INFO  : Dragons of Asgard 2 - Logan Jacobs/006 Logan Jacobs - Dragons of Asgard 2 - Chapter 5.mp3: Copied (new)
# 2024/07/23 13:43:13 INFO  : Dragons of Asgard 2 - Logan Jacobs/004 Logan Jacobs - Dragons of Asgard 2 - Chapter 3.mp3: Copied (new)
# 2024/07/23 13:43:13 INFO  : Dragons of Asgard 2 - Logan Jacobs/008 Logan Jacobs - Dragons of Asgard 2 - Chapter 7.mp3: Copied (new)
# 2024/07/23 13:43:13 INFO  : Dragons of Asgard 2 - Logan Jacobs/007 Logan Jacobs - Dragons of Asgard 2 - Chapter 6.mp3: Copied (new)
# 2024/07/23 13:43:14 INFO  : Dragons of Asgard 2 - Logan Jacobs/010 Logan Jacobs - Dragons of Asgard 2 - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:43:14 INFO  :    14.490 GiB / 46.378 GiB, 31%, 52.578 MiB/s, ETA 10m21s (xfr#281/968)
# 2024/07/23 13:43:14 INFO  : Dragons of Asgard 2 - Logan Jacobs/012 Logan Jacobs - Dragons of Asgard 2 - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:43:14 INFO  : Dragons of Asgard 2 - Logan Jacobs/009 Logan Jacobs - Dragons of Asgard 2 - Chapter 8.mp3: Copied (new)
# 2024/07/23 13:43:14 INFO  : Dragons of Asgard 2 - Logan Jacobs/014 Logan Jacobs - Dragons of Asgard 2 - Chapter 13.mp3: Copied (new)
# 2024/07/23 13:43:14 INFO  : Dragons of Asgard 2 - Logan Jacobs/013 Logan Jacobs - Dragons of Asgard 2 - Chapter 12.mp3: Copied (new)
# 2024/07/23 13:43:14 INFO  : Eric Vall - Dragon Emperor 7 - Human to Dragon to God Dragon Emperor, Book 7/Dragon Emperor 7 - Human to Dragon to God Dragon Emperor, Book 7  Audiobook-48843.mp4: Copied (new)
# 2024/07/23 13:43:17 INFO  : Dragons of Asgard 2 - Logan Jacobs/017 Logan Jacobs - Dragons of Asgard 2 - Chapter 16.mp3: Copied (new)
# 2024/07/23 13:43:17 INFO  : Dragons of Asgard 2 - Logan Jacobs/015 Logan Jacobs - Dragons of Asgard 2 - Chapter 14.mp3: Copied (new)
# 2024/07/23 13:43:17 INFO  : Dragons of Asgard 2 - Logan Jacobs/020 Logan Jacobs - Dragons of Asgard 2 - Chapter 19.mp3: Copied (new)
# 2024/07/23 13:43:17 INFO  : Dragons of Asgard 2 - Logan Jacobs/024 Logan Jacobs - Dragons of Asgard 2 - Chapter 23.mp3: Copied (new)
# 2024/07/23 13:43:17 INFO  : Dragons of Asgard 2 - Logan Jacobs/018 Logan Jacobs - Dragons of Asgard 2 - Chapter 17.mp3: Copied (new)
# 2024/07/23 13:43:17 INFO  : Dragons of Asgard 2 - Logan Jacobs/016 Logan Jacobs - Dragons of Asgard 2 - Chapter 15.mp3: Copied (new)
# 2024/07/23 13:43:17 INFO  : Dragons of Asgard 2 - Logan Jacobs/022 Logan Jacobs - Dragons of Asgard 2 - Chapter 21.mp3: Copied (new)
# 2024/07/23 13:43:18 INFO  : Dragons of Asgard 2 - Logan Jacobs/021 Logan Jacobs - Dragons of Asgard 2 - Chapter 20.mp3: Copied (new)
# 2024/07/23 13:43:18 INFO  : Dragons of Asgard 2 - Logan Jacobs/023 Logan Jacobs - Dragons of Asgard 2 - Chapter 22.mp3: Copied (new)
# 2024/07/23 13:43:18 INFO  : Dragons of Asgard 2 - Logan Jacobs/027 Logan Jacobs - Dragons of Asgard 2 - Chapter 26.mp3: Copied (new)
# 2024/07/23 13:43:18 INFO  : Dragons of Asgard 2 - Logan Jacobs/019 Logan Jacobs - Dragons of Asgard 2 - Chapter 18.mp3: Copied (new)
# 2024/07/23 13:43:19 INFO  :    14.743 GiB / 46.382 GiB, 32%, 52.038 MiB/s, ETA 10m22s (xfr#297/968)
# 2024/07/23 13:43:21 INFO  : Dragons of Asgard 2 - Logan Jacobs/030 Logan Jacobs - Dragons of Asgard 2 - End Credits.mp3: Copied (new)
# 2024/07/23 13:43:21 INFO  : Eric Vall - Dragon Emperor 16/001 Eric Vall - Dragon Emperor 16 - Opening Credits.mp3: Copied (new)
# 2024/07/23 13:43:21 INFO  : Dragons of Asgard 2 - Logan Jacobs/025 Logan Jacobs - Dragons of Asgard 2 - Chapter 24.mp3: Copied (new)
# 2024/07/23 13:43:21 INFO  : Dragons of Asgard 2 - Logan Jacobs/028 Logan Jacobs - Dragons of Asgard 2 - Chapter 27.mp3: Copied (new)
# 2024/07/23 13:43:22 INFO  : Eric Vall - Dragon Emperor 16/002 Eric Vall - Dragon Emperor 16 - Chapter 1.mp3: Copied (new)
# 2024/07/23 13:43:22 INFO  : Eric Vall - Dragon Emperor 16/003 Eric Vall - Dragon Emperor 16 - Chapter 2.mp3: Copied (new)
# 2024/07/23 13:43:22 INFO  : Dragons of Asgard 2 - Logan Jacobs/031 Logan Jacobs - Dragons of Asgard 2 - Outro.mp3: Copied (new)
# 2024/07/23 13:43:22 INFO  : Dragons of Asgard 2 - Logan Jacobs/026 Logan Jacobs - Dragons of Asgard 2 - Chapter 25.mp3: Copied (new)
# 2024/07/23 13:43:22 INFO  : Dragons of Asgard 2 - Logan Jacobs/029 Logan Jacobs - Dragons of Asgard 2 - Chapter 28.mp3: Copied (new)
# 2024/07/23 13:43:23 INFO  : Eric Vall - Dragon Emperor 16/007 Eric Vall - Dragon Emperor 16 - Chapter 6.mp3: Copied (new)
# 2024/07/23 13:43:23 INFO  : Eric Vall - Dragon Emperor 16/004 Eric Vall - Dragon Emperor 16 - Chapter 3.mp3: Copied (new)
# 2024/07/23 13:43:23 INFO  : Eric Vall - Dragon Emperor 16/009 Eric Vall - Dragon Emperor 16 - Chapter 8.mp3: Copied (new)
# 2024/07/23 13:43:23 INFO  : Eric Vall - Dragon Emperor 16/006 Eric Vall - Dragon Emperor 16 - Chapter 5.mp3: Copied (new)
# 2024/07/23 13:43:23 INFO  : Dragons of Asgard 2 - Logan Jacobs/cover.jpg: Copied (new)
# 2024/07/23 13:43:24 INFO  :    15.012 GiB / 46.033 GiB, 33%, 52.199 MiB/s, ETA 10m8s (xfr#311/968)
# 2024/07/23 13:43:24 INFO  : Eric Vall - Dragon Emperor 16/010 Eric Vall - Dragon Emperor 16 - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:43:24 INFO  : Eric Vall - Dragon Emperor 16/011 Eric Vall - Dragon Emperor 16 - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:43:24 INFO  : Eric Vall - Dragon Emperor 16/012 Eric Vall - Dragon Emperor 16 - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:43:25 INFO  : Eric Vall - Dragon Emperor 16/008 Eric Vall - Dragon Emperor 16 - Chapter 7.mp3: Copied (new)
# 2024/07/23 13:43:25 INFO  : Eric Vall - Dragon Emperor 16/005 Eric Vall - Dragon Emperor 16 - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:43:28 INFO  : Eric Vall - Dragon Emperor 17/010 Eric Vall - Dragon Emperor 17 - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:43:29 INFO  :    15.161 GiB / 46.466 GiB, 33%, 44.787 MiB/s, ETA 11m55s (xfr#317/968)
# 2024/07/23 13:43:31 INFO  : Eric Vall - Dragon Emperor 17/012 Eric Vall - Dragon Emperor 17 - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:43:31 INFO  : Eric Vall - Dragon Emperor 17/011 Eric Vall - Dragon Emperor 17 - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:43:31 INFO  : Eric Vall - Dragon Emperor 17/015 Eric Vall - Dragon Emperor 17 - Chapter 14.mp3: Copied (new)
# 2024/07/23 13:43:32 INFO  : Eric Vall - Dragon Emperor 17/cover.jpg: Copied (new)
# 2024/07/23 13:43:32 INFO  : Eric Vall - Dragon Emperor 17/016 Eric Vall - Dragon Emperor 17 - Chapter 15.mp3: Copied (new)
# 2024/07/23 13:43:33 INFO  : Eric Vall - Dragon Emperor 5/DragonEmperor5HumantoDragontoGod.mp3: Copied (new)
# 2024/07/23 13:43:34 INFO  :    15.520 GiB / 46.425 GiB, 33%, 53.928 MiB/s, ETA 9m46s (xfr#323/968)
# 2024/07/23 13:43:34 INFO  : Eric Vall - Dragon Emperor 17/017 Eric Vall - Dragon Emperor 17 - End Credits.mp3: Copied (new)
# 2024/07/23 13:43:34 INFO  : Jack Porter - The Bastard - Book 1/50009296._SY475_.jpg: Copied (new)
# 2024/07/23 13:43:34 INFO  : Logan Jacobs - Arena/Arena.jpg: Copied (new)
# 2024/07/23 13:43:34 INFO  : Logan Jacobs - Arena/Logan Jacobs - Arena.sfv: Copied (new)
# 2024/07/23 13:43:35 INFO  : Eric Vall - Dragon Emperor 17/014 Eric Vall - Dragon Emperor 17 - Chapter 13.mp3: Copied (new)
# 2024/07/23 13:43:35 INFO  : Eric Vall - Dragon Emperor 17/013 Eric Vall - Dragon Emperor 17 - Chapter 12.mp3: Copied (new)
# 2024/07/23 13:43:36 INFO  : Logan Jacobs - Arena/Arena.m4b: Copied (new)
# 2024/07/23 13:43:38 INFO  : Jack Porter - The Bastard - Book 1/The Bastard - Book 1.mp3: Copied (new)
# 2024/07/23 13:43:39 INFO  :    15.907 GiB / 46.501 GiB, 34%, 60.763 MiB/s, ETA 8m35s (xfr#331/968)
# 2024/07/23 13:43:40 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 02.mp3: Copied (new)
# 2024/07/23 13:43:40 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 03.mp3: Copied (new)
# 2024/07/23 13:43:40 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/cover.jpg: Copied (new)
# 2024/07/23 13:43:40 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 11.mp3: Copied (new)
# 2024/07/23 13:43:41 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 08.mp3: Copied (new)
# 2024/07/23 13:43:41 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 05.mp3: Copied (new)
# 2024/07/23 13:43:41 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 07.mp3: Copied (new)
# 2024/07/23 13:43:41 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 09.mp3: Copied (new)
# 2024/07/23 13:43:41 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 04.mp3: Copied (new)
# 2024/07/23 13:43:41 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 01.mp3: Copied (new)
# 2024/07/23 13:43:41 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 06.mp3: Copied (new)
# 2024/07/23 13:43:41 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 10.mp3: Copied (new)
# 2024/07/23 13:43:41 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 15.mp3: Copied (new)
# 2024/07/23 13:43:42 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 12.mp3: Copied (new)
# 2024/07/23 13:43:42 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 13.mp3: Copied (new)
# 2024/07/23 13:43:42 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 16.mp3: Copied (new)
# 2024/07/23 13:43:43 INFO  : Gun Mage 2/Chapter 1 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:43 INFO  : Gun Mage 2/Chapter 10 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:44 INFO  :    16.099 GiB / 46.418 GiB, 35%, 55.569 MiB/s, ETA 9m18s (xfr#349/968)
# 2024/07/23 13:43:44 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor/Chapter 14.mp3: Copied (new)
# 2024/07/23 13:43:45 INFO  : Gun Mage 2/Chapter 11 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:45 INFO  : Gun Mage 2/End Credits - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:45 INFO  : Gun Mage 2/Chapter 14 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:46 INFO  : Gun Mage 2/Logan Jacobs - Gun Mage 2.m3u: Copied (new)
# 2024/07/23 13:43:46 INFO  : Gun Mage 2/Opening Credits - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:46 INFO  : Gun Mage 2/Chapter 12 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:47 INFO  : Gun Mage 2/Chapter 9 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:47 INFO  : Gun Mage 2/Chapter 4 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:47 INFO  : Gun Mage 2/Chapter 3 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:47 INFO  : Gun Mage 2/Chapter 13 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:49 INFO  :    16.168 GiB / 46.525 GiB, 35%, 42.576 MiB/s, ETA 12m10s (xfr#360/968)
# 2024/07/23 13:43:49 INFO  : Logan Jacobs - Arena, Book 3/Arena, Book 3.cue: Copied (new)
# 2024/07/23 13:43:51 INFO  : Gun Mage 2/Chapter 15 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:51 INFO  : Gun Mage 2/Chapter 5 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:51 INFO  : Gun Mage 2/Chapter 6 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:51 INFO  : Gun Mage 2/Chapter 16 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:51 INFO  : Gun Mage 2/Chapter 8 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:52 INFO  : Gun Mage 2/Chapter 2 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:52 INFO  : Logan Jacobs - Arena, Book 3/Arena, Book 3.jpg: Copied (new)
# 2024/07/23 13:43:53 INFO  : Logan Jacobs - Arena, Book 3/Arena, Book 3.nfo: Copied (new)
# 2024/07/23 13:43:54 INFO  : Gun Mage 2/Chapter 7 - Gun Mage 2 - Logan Jacobs.m4a: Copied (new)
# 2024/07/23 13:43:54 INFO  :    16.598 GiB / 46.496 GiB, 36%, 55.438 MiB/s, ETA 9m12s (xfr#370/968)
# 2024/07/23 13:43:57 INFO  : Logan Jacobs - Arena Book 4/Arena Book 4.jpg: Copied (new)
# 2024/07/23 13:43:59 INFO  :    17.167 GiB / 46.509 GiB, 37%, 72.385 MiB/s, ETA 6m55s (xfr#371/968)
# 2024/07/23 13:43:59 INFO  : Logan Jacobs - Arena Book 4/Arena Book 4.nfo: Copied (new)
# 2024/07/23 13:44:00 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/001 Logan Jacobs - Kill Monsters, Get Rich 1 - Opening Credits.mp3: Copied (new)
# 2024/07/23 13:44:00 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/004 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 3.mp3: Copied (new)
# 2024/07/23 13:44:01 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/002 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 1.mp3: Copied (new)
# 2024/07/23 13:44:01 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/008 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 7.mp3: Copied (new)
# 2024/07/23 13:44:01 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/012 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 11.mp3: Copied (new)
# 2024/07/23 13:44:01 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/013 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 12.mp3: Copied (new)
# 2024/07/23 13:44:02 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/011 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 10.mp3: Copied (new)
# 2024/07/23 13:44:02 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/009 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 8.mp3: Copied (new)
# 2024/07/23 13:44:03 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/003 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 2.mp3: Copied (new)
# 2024/07/23 13:44:03 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/014 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 13.mp3: Copied (new)
# 2024/07/23 13:44:03 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/010 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 9.mp3: Copied (new)
# 2024/07/23 13:44:03 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/005 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:44:03 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/007 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 6.mp3: Copied (new)
# 2024/07/23 13:44:04 INFO  :    17.661 GiB / 46.278 GiB, 38%, 80.731 MiB/s, ETA 6m2s (xfr#385/968)
# 2024/07/23 13:44:04 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/015 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 14.mp3: Copied (new)
# 2024/07/23 13:44:04 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/006 Logan Jacobs - Kill Monsters, Get Rich 1 - Chapter 5.mp3: Copied (new)
# ...
# 2024/07/23 13:50:03 INFO  : Eric Vall - Dragon Emperor 17/005 Eric Vall - Dragon Emperor 17 - Chapter 4.mp3: Copied (new)
# 2024/07/23 13:50:04 INFO  :    45.399 GiB / 46.525 GiB, 98%, 107.957 MiB/s, ETA 10s
# 2024/07/23 13:50:04 INFO  : The Dungeon Master Series/Book 07 - Dungeon Master 7/Éric Vall - Dungeon Master 7.mp3: Copied (new)
# 2024/07/23 13:50:06 INFO  : The Dungeon Master Series/Book 08 - Dungeon Master 8/Éric Vall - Dungeon Master 8.mp3: Copied (new)
# 2024/07/23 13:50:06 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 10/Metal Mage 10.mp3: Copied (new)
# 2024/07/23 13:50:08 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 6/Metal Mage 6.m4b: Copied (new)
# 2024/07/23 13:50:09 INFO  :    45.817 GiB / 46.525 GiB, 98%, 102.292 MiB/s, ETA 7s
# 2024/07/23 13:50:09 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 7/Metal Mage 7.m4b: Copied (new)
# 2024/07/23 13:50:11 INFO  : Eric Vall - Metal Mage/Metal Mage.m4b: Copied (new)
# 2024/07/23 13:50:13 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 15/Metal Mage 15.mp3: Copied (new)
# 2024/07/23 13:50:14 INFO  :    46.005 GiB / 46.525 GiB, 99%, 85.098 MiB/s, ETA 6s
# 2024/07/23 13:50:17 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 8/Eric Vall - Succubus Lord 8.m4b: Copied (new)
# 2024/07/23 13:50:19 INFO  :    46.197 GiB / 46.525 GiB, 99%, 72.245 MiB/s, ETA 4s
# 2024/07/23 13:50:22 INFO  : Logan Jacobs - God of Magic Series Books 1-4/Logan Jacobs - God of Magic 4/God of Magic 4.m4b: Copied (new)
# 2024/07/23 13:50:24 INFO  :    46.333 GiB / 46.525 GiB, 100%, 59.823 MiB/s, ETA 3s
# 2024/07/23 13:50:27 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 9/Eric Vall - Metal Mage 9.mp3: Copied (new)
# 2024/07/23 13:50:29 INFO  :    46.439 GiB / 46.525 GiB, 100%, 49.192 MiB/s, ETA 1s
# 2024/07/23 13:50:34 INFO  :    46.525 GiB / 46.525 GiB, 100%, 41.236 MiB/s, ETA 0s
# 2024/07/23 13:50:35 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 7/Eric Vall - Succubus Lord 7.mp3: Copied (new)
# 2024/07/23 13:50:36 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor 2: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:36 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 5: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:36 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:36 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 7: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus lord 15: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 2: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 9: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 1: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 10: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 12: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 11: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 8: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 14: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 4: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 6: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 13: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Succubus Lord (RePack)/Eric Vall - Succubus Lord 10: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor 3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Dragon Emperor 1-3/Eric Vall - Dragon Emperor: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:37 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 5: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 9: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 2: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 7: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 11: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 8: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 12: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 15: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 4: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 14: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Logan Jacobs - God of Magic Series Books 1-4/Logan Jacobs - God of Magic 2: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Logan Jacobs - God of Magic Series Books 1-4/Logan Jacobs - God of Magic 4: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 6: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Logan Jacobs - God of Magic Series Books 1-4/Logan Jacobs - God of Magic: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Evil Genius 6_ Becoming the Apex Supervillain - Logan Jacobs/.pad: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Eric Vall - Metal Mage/Eric Vall - Metal Mage 13: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs/.pad: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : The Dungeon Master Series/Book 01 - Dungeon Master: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:38 INFO  : Logan Jacobs - God of Magic Series Books 1-4/Logan Jacobs - God of Magic 3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:39 INFO  :    46.525 GiB / 46.525 GiB, 100%, 29.863 MiB/s, ETA 0s
# 2024/07/23 13:50:39 INFO  : The Dungeon Master Series/Book 02 - Dungeon Master 2: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:39 INFO  : champion 1-3/.pad: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:39 INFO  : The Dungeon Master Series/Book 03 - Dungeon Master 3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:39 INFO  : The Dungeon Master Series/Book 05 - Dungeon Master 5: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:39 INFO  : The Dungeon Master Series/Book 07 - Dungeon Master 7: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:39 INFO  : The Dungeon Master Series/Book 08 - Dungeon Master 8: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:39 INFO  : The Dungeon Master Series/Book 06 - Dungeon Master 6: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:39 INFO  : The Dungeon Master Series/Book 04 - Dungeon Master 4: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Divine Collector: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Alex in Haremland 2 - Logan Jacobs: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Conquering a Bloodthirsty Earth Vampire Lord, Book 3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Backyard Dungeon 2 - Logan Jacobs: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Book 01 - Dragons Of Asgard: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : 1-5: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Divine Collector 2: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Book 1 - Dragon Conjurer: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Book 03 - Monster Girl Base 3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Dragon Conjurer 4 - Eric Vall: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Book 04 - Soul Gem Collector 4: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Dragon Emperor 1-3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Book 02 - Monster Girl Base 2: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Dragon Conjurer 5 - Eric Vall: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:40 INFO  : Book 05 - Arena 5: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:41 INFO  : Divine Collector 3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:41 INFO  : Book 01 - Monster Girl Base: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:41 INFO  : Dragon Emperor 11 by Eric Vall: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:41 INFO  : Backyard Dungeon - Logan Jacobs: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:41 INFO  : Alex in Haremland: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:41 INFO  : Dragons of Asgard 3 - Logan Jacobs: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Emperor 6: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Emperor 14: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Emperor 8: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Emperor 16: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Emperor 17: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Emperor 5: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Emperor - Book 9: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Emperor 7 - Human to Dragon to God Dragon Emperor, Book 7: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Succubus Lord: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Conjurer 3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Dragons of Asgard 2 - Logan Jacobs: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Emperor 15: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Dragon Emperor 12 by Eric Vall: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Dragon Emperor 13 by Eric Vall: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Metal Mage: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Dragon Conjurer 2: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Evil Genius 6_ Becoming the Apex Supervillain - Logan Jacobs: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Eric Vall - Succubus Lord (RePack): Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:42 INFO  : Gun Mage 2: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Jack Porter - The Bastard - Book 1: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Logan Jacobs - Arena Book 4: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Logan Jacobs - Arena: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Logan Jacobs - Arena, Book 3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Monster Girl Base 4 - Logan Jacobs: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Logan Jacobs - Sellsword, The Amoral Hero: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Logan Jacobs - God of Magic Series Books 1-4: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Logan Jacobs - Blood Mage: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Soul Gem Collector 5 - Logan Jacobs: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : The Dungeon Master Series: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Lottery King 1 - Eric Vall: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Succubus Lord 18: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Vampire Sire 1: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Succubus Lord 19: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Succubus Lord 17 by Eric Vall: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Wrath of the Dragon 2 - Eric Vall: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Wrath of the Dragon 3 - Eric Vall: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Kill Monsters, Get Rich 1 - Logan Jacobs: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:43 INFO  : Wrath of the Dragon - Eric Vall: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:44 INFO  : champion 1-3: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:44 INFO  :    46.525 GiB / 46.525 GiB, 100%, 21.626 MiB/s, ETA 0s
# 2024/07/23 13:50:44 INFO  : mage-assassin: Set directory modification time (using DirSetModTime)
# 2024/07/23 13:50:44 INFO  :    46.525 GiB / 46.525 GiB, 100%, 21.626 MiB/s, ETA 0s
#             <center>
#                 <h2 style="font-family:monospace;color:#28a745;">
#                     👍 Operation Sync has been successfully completed.
#                 </h2>
#                 <br>
#             </center>

# %%
# !cp /root/.config/rclone/rclone.conf /content/drive/MyDrive/

# %%
# !rclone config
